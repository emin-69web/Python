# %%
isim = (input("İsmizi Giriniz"))
soyisim = (input("Soyisminizi Giriniz"))
yaş = int(input("Yaşinizi Giriniz"))
şehir = (input("Oturdugunuz Şehri Giriniz"))
meslek = (input("mesleğinizi Giriniz"))
toplam_harf =len(isim)+len(soyisim)
print(f"isim ve soydanızın toplam harf sayısı : {toplam_harf}")
print(f"Merhaba! Ben {isim} {soyisim} \n{yaş} Yaşindayim \n{şehir} Şehrinde oturuyorum \nMesleğim {meslek}")

ŞUANKİ_YIL = 2026
DOĞUM_YILI = int(input("Doğum Tarihini Gir"))
yaş = ŞUANKİ_YIL - DOĞUM_YILI 
yaşınızın_10_yıl_sonraki = yaş + 10

print(f"Yaşın{yaş}")
print(f"10 Yıl sonra  {yaşınızın_10_yıl_sonraki} yaşında olacaksın")
# Out:
# isim ve soydanızın toplam harf sayısı : 11
# Merhaba! Ben emin birinci
# 21 Yaşindayim
# istanbul Şehrinde oturuyorum
# Mesleğim öğrenci
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       8 print(f"Merhaba! Ben {isim} {soyisim} \n{yaş} Yaşindayim \n{şehir} Şehrinde oturuyorum \nMesleğim {meslek}")
#      10 ŞUANKİ_YIL = 2026
# ---> 11 DOĞUM_YILI = int(input("Doğum Tarihini Gir"))
#      12 yaş = ŞUANKİ_YIL - DOĞUM_YILI
#      13 yaşınızın_10_yıl_sonraki = yaş + 10
#
# ValueError: invalid literal for int() with base 10: '01 02 2005'
